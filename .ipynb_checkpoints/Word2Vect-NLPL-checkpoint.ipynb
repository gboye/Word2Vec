# %% [markdown]
# # Tests de Word2Vec avec des vecteurs [NLPL](http://vectors.nlpl.eu/repository/)

# %% [markdown]
# ## Français
# Corpus :
# - French CoNLL17 corpus
#     - français, minuscules, sans lemmes, sans tags
#     - 5494845765 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - skipgram
# - 100 dimensions
# - fenêtre 10 mots
# - taille du vocabulaire : 2567698 mots

# %%
import os,gensim
from gensim.models.keyedvectors import KeyedVectors
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

data_path= "/Volumes/Lexar/NLPL/"

# %%
path_to_modelFr = os.path.join(data_path,'43/model.bin')
#Load W2V model. This will take some time.
modelFr = KeyedVectors.load_word2vec_format(path_to_modelFr, binary=True)
print('done loading Word2Vec')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/h7/0cygyb1j7cn88gdc53db7m6w0000gn/T/ipykernel_20274/2141034525.py in <module>
#       1 path_to_modelFr = os.path.join(data_path,'43/model.bin')
#       2 #Load W2V model. This will take some time.
# ----> 3 modelFr = KeyedVectors.load_word2vec_format(path_to_modelFr, binary=True)
#       4 print('done loading Word2Vec')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1545         """
#    1546         # from gensim.models.word2vec import load_word2vec_format
# -> 1547         return _load_word2vec_format(
#    1548             cls, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
#    1549             limit=limit, datatype=datatype)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, binary_chunk_size)
#     273
#     274     logger.info("loading projection weights from %s", fname)
# --> 275     with utils.open(fname, 'rb') as fin:
#     276         header = utils.to_unicode(fin.readline(), encoding=encoding)
#     277         vocab_size, vector_size = (int(x) for x in header.split())  # throws for invalid file format
#
# ~/opt/anaconda3/lib/python3.9/site-packages/smart_open/smart_open_lib.py in open(uri, mode, buffering, encoding, errors, newline, closefd, opener, ignore_ext, transport_params)
#     300         transport_params = {}
#     301
# --> 302     fobj = _shortcut_open(
#     303         uri,
#     304         mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/smart_open/smart_open_lib.py in _shortcut_open(uri, mode, ignore_ext, buffering, encoding, errors)
#     515     #
#     516     if six.PY3:
# --> 517         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering, **open_kwargs)
#     518     elif not open_kwargs:
#     519         return _builtin_open(parsed_uri.uri_path, mode, buffering=buffering)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/Lexar/NLPL/43/model.bin'

# %%
modelFr.most_similar("semi-séchées",topn=10)
# Out:
# [('grilées', 0.9388961791992188),
#  ('câprons', 0.9372661709785461),
#  ('ciboulett', 0.9364157915115356),
#  ('muscadé', 0.9338451027870178),
#  ('basessaucessauce', 0.932698130607605),
#  ('oeufsgâteau', 0.9322818517684937),
#  ('lardons*', 0.9304170608520508),
#  ('e...entrée', 0.9303704500198364),
#  ('mini-tomates', 0.9290671348571777),
#  ('-pâtes', 0.9287031292915344)]

# %%
modelFr.most_similar(positive=["prince","avocate"],negative=["avocat"],topn=5)
# Out:
# [('princesse', 0.7751262187957764),
#  ('feodorovna', 0.7274991273880005),
#  ('fiancée', 0.7253321409225464),
#  ('märtha', 0.7227485775947571),
#  ('héritère', 0.7172694206237793)]

# %%
modelFr.most_similar(positive=["cyclisme","médecin"],negative=["cycliste"],topn=20)
# Out:
# [('gynécologue', 0.7741674780845642),
#  ('obstétricien', 0.7543758749961853),
#  ('stomatologiste', 0.745745062828064),
#  ('dentiste', 0.7311486601829529),
#  ('pédiatre', 0.7268843054771423),
#  ('angiologue', 0.7191413640975952),
#  ('gastro-entérologue', 0.7134258151054382),
#  ('traumatologue', 0.7117855548858643),
#  ('praticien', 0.7115322351455688),
#  ('cardiologue', 0.7089608907699585),
#  ('médécin', 0.7067649364471436),
#  ('acupuncteur', 0.7060045003890991),
#  ('nephrologue', 0.7046054005622864),
#  ('chirurgien', 0.7023006677627563),
#  ('sexologue', 0.7013766765594482),
#  ('gastroentérologue', 0.7008221745491028),
#  ('homéopathe', 0.6992183327674866),
#  ('urologue', 0.6991825103759766),
#  ('medecin', 0.6990585923194885),
#  ('pharmacien', 0.6964228749275208)]

# %% [markdown]
# ## Représentation des voisinages en 2D

# %%
def display_closestwords_tsnescatterplot(model, word, size,topn=10):
    
    arr = np.empty((0,size), dtype='f')
    word_labels = [word]
    close_words = model.similar_by_word(word,topn=topn)
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)
    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    plt.figure(figsize=(50,50))
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points',fontsize=50)
        plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
        plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
mot="grand"
display_closestwords_tsnescatterplot(modelFr, mot, 100,topn=100)

# %%
modelFr.doesnt_match("électricien mécanicien peintre platrier maçon prof voiture".split(" "))
# Out:
# 'voiture'

# %%
modelFr.doesnt_match("vélaire alvéolaire nasale dorsale vibrante petit".split(" "))
# Out:
# 'petit'

# %% [markdown]
# ## Anglais Fasttext
# Corpus :
# - English Wikipedia February 2017
#     - anglais, min/maj, lemmes, tagged
#     - 2252637050 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - Fasttext Skipgram
# - 300 dimensions
# - fenêtre 5 mots
# - taille du vocabulaire : 273930 mots

# %%
path_to_modelEn = os.path.join(data_path,'9/parameters.bin')
#Load W2V model. This will take some time.
modelEn = gensim.models.fasttext.load_facebook_vectors(path_to_modelEn)
print('done loading Word2Vec')
# Out:
# done loading Word2Vec

# %%
modelEn.most_similar("apple")
# Out:
# [('pear', 0.7719689011573792),
#  ('strawberry', 0.7652075290679932),
#  ('cherry', 0.7519378066062927),
#  ('blueberry', 0.7249221801757812),
#  ('peach', 0.7196301221847534),
#  ('almond', 0.714466392993927),
#  ('apricot', 0.7141430377960205),
#  ('plum', 0.6914741396903992),
#  ('berry', 0.6877110004425049),
#  ('fruit', 0.687423586845398)]

# %%
modelEn.most_similar(positive=["heat_VERB","summary_NOUN"],negative=["heat_NOUN"],topn=15)
# Out:
# [('summary', 0.736221194267273),
#  ('Summary', 0.5815476179122925),
#  ('summarize', 0.5486070513725281),
#  ('summarization', 0.5363128781318665),
#  ('reviewable', 0.5063964128494263),
#  ('pleading', 0.506040096282959),
#  ('rulemaking', 0.5056465864181519),
#  ('subparagraph', 0.5045183897018433),
#  ('Indictment', 0.49866044521331787),
#  ('one-sentence', 0.49582481384277344),
#  ('rulemake', 0.4924849271774292),
#  ('Impeachment', 0.4897017180919647),
#  ('indictment', 0.4886951446533203),
#  ('appealable', 0.48840218782424927),
#  ('andcoordinate', 0.4880529046058655)]

# %%
modelEn.doesnt_match("breakfast cereal field dinner lunch".split(" "))
# Out:
# 'field'

# %% [markdown]
# ## Anglais
# Corpus :
# - British National Corpus
#     - anglais, min/maj, lemmes, tagged
#     - 1903181185 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - Skipgram
# - 300 dimensions
# - fenêtre 10 mots
# - taille du vocabulaire : 163473 mots

# %%
path_to_modelBNC = os.path.join(data_path,'0/model.bin')
#Load W2V model. This will take some time.
modelBNC = KeyedVectors.load_word2vec_format(path_to_modelBNC, binary=True)
print('done loading Word2Vec')
# Out:
# done loading Word2Vec

# %%
modelBNC.most_similar("eat_VERB")
# Out:
# [('elevense_NOUN', 0.7003511190414429),
#  ('fattening_ADJ', 0.6969293355941772),
#  ('overindulgence_NOUN', 0.6924725770950317),
#  ('high-fat_NOUN', 0.689265251159668),
#  ('Dieters_PROPN', 0.6847373247146606),
#  ('macrobiotic_ADJ', 0.6825563907623291),
#  ('high-sugar_ADJ', 0.6802963018417358),
#  ('meal-time_NOUN', 0.6788443922996521),
#  ('spaghetti::bolognaise_NOUN', 0.6787879467010498),
#  ('rissole_NOUN', 0.678442120552063)]

# %%
modelBNC.most_similar(positive=["king_NOUN","woman_NOUN"],negative=["man_NOUN"],topn=5)
# Out:
# [('queen_NOUN', 0.5085595846176147),
#  ('coronation_NOUN', 0.48925459384918213),
#  ('kingship_NOUN', 0.4846012592315674),
#  ('monarch_NOUN', 0.4805525541305542),
#  ('alhred_ADJ', 0.475553035736084)]

# %%
modelBNC.doesnt_match("breakfast_NOUN cereal_NOUN dinner_NOUN lunch_NOUN".split(" "))
# Out:
# 'cereal_NOUN'
