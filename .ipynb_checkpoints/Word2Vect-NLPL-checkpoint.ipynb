# %% [markdown]
# # Tests de Word2Vec avec des vecteurs [NLPL](http://vectors.nlpl.eu/repository/)

# %% [markdown]
# ## Français (NLPL/43)
# Corpus :
# - French CoNLL17 corpus
#     - français, minuscules, sans lemmes, sans tags
#     - 5494845765 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - skipgram
# - 100 dimensions
# - fenêtre 10 mots
# - taille du vocabulaire : 2567698 mots

# %%
import os,gensim
from gensim.models.keyedvectors import KeyedVectors
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

data_path= "/votre/chemin/vers/nlpl/" # commentez les autres chemins
data_path="/Users/gilles/Downloads/"

# %%
path_to_modelFr = os.path.join(data_path,'43/model.bin')
#Load W2V model. This will take some time.
modelFr = KeyedVectors.load_word2vec_format(path_to_modelFr, binary=True)
print('done loading Word2Vec')
# Out:
# done loading Word2Vec

# %%
modelFr.most_similar("roi",topn=10)
# Out:
# [('régent', 0.8303719758987427),
#  ('prince', 0.813419759273529),
#  ('souverain', 0.8035577535629272),
#  ('chambellan', 0.80156409740448),
#  ('sawlu', 0.7879902124404907),
#  ('ben-hadad', 0.7860089540481567),
#  ('athalaric', 0.785047173500061),
#  ('régente', 0.783330500125885),
#  ('1154-1166', 0.7829881310462952),
#  ('thorisind', 0.7824245691299438)]

# %%
modelFr.most_similar(positive=["roi","femme"],negative=["homme"],topn=5)
# Out:
# [('reine', 0.7886008024215698),
#  ('régente', 0.7626445293426514),
#  ('waccho', 0.7577704191207886),
#  ('reine-mère', 0.7507311701774597),
#  ('rigonde', 0.7384146451950073)]

# %%
modelFr.most_similar(positive=["cyclisme","maçon"],negative=["cycliste"],topn=5)
# Out:
# [('maconnerie', 0.6592904925346375),
#  ('plâtrier', 0.6461007595062256),
#  ('plaquiste', 0.6455990672111511),
#  ('briqueteur', 0.6410598754882812),
#  ('coffreur', 0.6409931778907776)]

# %% [markdown]
# ## Représentation des voisinages en 2D
# TSNE permet une réduction de dimension pour visualiser les voisinages sur une carte

# %%
def display_closestwords_tsnescatterplot(model, word, size,topn=10):
    
    arr = np.empty((0,size), dtype='f')
    word_labels = [word]
    close_words = model.similar_by_word(word,topn=topn)
    arr = np.append(arr, np.array([model[word]]), axis=0)
    for wrd_score in close_words:
        wrd_vector = model[wrd_score[0]]
        word_labels.append(wrd_score[0])
        arr = np.append(arr, np.array([wrd_vector]), axis=0)
        
    tsne = TSNE(n_components=2, random_state=0)
    np.set_printoptions(suppress=True)
    Y = tsne.fit_transform(arr)
    x_coords = Y[:, 0]
    y_coords = Y[:, 1]
    plt.figure(figsize=(50,50))
    plt.scatter(x_coords, y_coords)

    for label, x, y in zip(word_labels, x_coords, y_coords):
        plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords='offset points',fontsize=50)
        plt.xlim(x_coords.min()+0.00005, x_coords.max()+0.00005)
        plt.ylim(y_coords.min()+0.00005, y_coords.max()+0.00005)
    plt.show()

# %%
mot="roi"
display_closestwords_tsnescatterplot(modelFr, mot, 100,topn=100)

# %% [markdown]
# ### doesnt_match
# doesnt_match cherche le vecteur le plus différent des autres dans une liste => chercher l'intrus

# %%
modelFr.doesnt_match(['électricien','mécanicien','peintre','platrier','maçon','prof','voiture'])
# Out:
# 'voiture'

# %%
modelFr.doesnt_match("vélaire alvéolaire nasale dorsale vibrante petit".split(" "))
# Out:
# 'petit'

# %% [markdown]
# ## Anglais Fasttext (NLPL/9)
# Corpus :
# - English Wikipedia February 2017
#     - anglais, min/maj, lemmes, tagged
#     - 2252637050 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - Fasttext Skipgram
# - 300 dimensions
# - fenêtre 5 mots
# - taille du vocabulaire : 273930 mots

# %%
path_to_modelEn = os.path.join(data_path,'9/parameters.bin')
#Load W2V model. This will take some time.
modelEn = gensim.models.fasttext.load_facebook_vectors(path_to_modelEn)
print('done loading Word2Vec')
# Out:
# done loading Word2Vec

# %% [markdown]
# ### Modèles FastText
# Les modèles FastText traitent non seulement les contextes des mots mais aussi ceux des N-grams. De ce fait, ils sont capables de fournir des vecteurs pour des mots qui ne sont pas dans le corpus du moment que les N-grams qui les composent sont effectivement dans le corpus.

# %%
modelEn.most_similar("apple")
# Out:
# [('pear', 0.7719690203666687),
#  ('strawberry', 0.7652074694633484),
#  ('cherry', 0.7519378662109375),
#  ('blueberry', 0.7249220609664917),
#  ('peach', 0.7196300625801086),
#  ('almond', 0.714466392993927),
#  ('apricot', 0.7141430377960205),
#  ('plum', 0.691474199295044),
#  ('berry', 0.6877110004425049),
#  ('fruit', 0.687423586845398)]

# %%
modelEn.most_similar(positive=["heat_VERB","summary_NOUN"],negative=["heat_NOUN"],topn=15)
# Out:
# [('summary', 0.736221194267273),
#  ('Summary', 0.5815476179122925),
#  ('summarize', 0.5486070513725281),
#  ('summarization', 0.5363128185272217),
#  ('reviewable', 0.5063964128494263),
#  ('pleading', 0.5060400366783142),
#  ('rulemaking', 0.5056465864181519),
#  ('subparagraph', 0.5045183897018433),
#  ('Indictment', 0.4986603856086731),
#  ('one-sentence', 0.49582481384277344),
#  ('rulemake', 0.4924849271774292),
#  ('Impeachment', 0.4897017478942871),
#  ('indictment', 0.4886951446533203),
#  ('appealable', 0.48840218782424927),
#  ('andcoordinate', 0.48805293440818787)]

# %%
modelEn.most_similar("spling")
# Out:
# [('spline', 0.70341557264328),
#  ('splint', 0.5943868160247803),
#  ('flaking', 0.5565938949584961),
#  ('buckling', 0.5555928945541382),
#  ('spalling', 0.5533570051193237),
#  ('compressive', 0.5518985986709595),
#  ('frictional', 0.5509396195411682),
#  ('meshing', 0.5497676134109497),
#  ('deformation', 0.542177140712738),
#  ('bevel', 0.5387728810310364)]

# %%
modelEn.doesnt_match("breakfast cereal field dinner lunch".split(" "))
# Out:
# 'field'

# %% [markdown]
# ## Anglais
# Corpus :
# - British National Corpus
#     - anglais, min/maj, lemmes, tagged
#     - 1903181185 tokens
#
# Créé par Andrey Kutuzov (andreku@ifi.uio.no)
#
# Paramètres :
# - Skipgram
# - 300 dimensions
# - fenêtre 10 mots
# - taille du vocabulaire : 163473 mots

# %%
path_to_modelBNC = os.path.join(data_path,'0/model.bin')
#Load W2V model. This will take some time.
modelBNC = KeyedVectors.load_word2vec_format(path_to_modelBNC, binary=True)
print('done loading Word2Vec')
# Out:
# done loading Word2Vec

# %%
modelBNC.most_similar("eat_VERB")
# Out:
# [('elevense_NOUN', 0.7003512382507324),
#  ('fattening_ADJ', 0.6969294548034668),
#  ('overindulgence_NOUN', 0.6924726963043213),
#  ('high-fat_NOUN', 0.689265251159668),
#  ('Dieters_PROPN', 0.6847373247146606),
#  ('macrobiotic_ADJ', 0.6825563907623291),
#  ('high-sugar_ADJ', 0.6802963018417358),
#  ('meal-time_NOUN', 0.6788443326950073),
#  ('spaghetti::bolognaise_NOUN', 0.678787887096405),
#  ('rissole_NOUN', 0.6784420013427734)]

# %%
modelBNC.most_similar(positive=["king_NOUN","woman_NOUN"],negative=["man_NOUN"],topn=5)
# Out:
# [('queen_NOUN', 0.5085595846176147),
#  ('coronation_NOUN', 0.48925459384918213),
#  ('kingship_NOUN', 0.4846012592315674),
#  ('monarch_NOUN', 0.4805525541305542),
#  ('alhred_ADJ', 0.475553035736084)]

# %%
modelBNC.doesnt_match("breakfast_NOUN cereal_NOUN dinner_NOUN lunch_NOUN".split(" "))
# Out:
# 'cereal_NOUN'
